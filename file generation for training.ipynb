# %%
# ConcreteCrack Dataset 참조 : https://aihub.or.kr/aidata/34141

# %%
# 내 구글 드라이브에 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Training 준비를 위한 ConcreteCrack Dataset 복사
# !cp -r '/content/gdrive/MyDrive/ConcreteCrack_Detection/dataset' .

# %%
# Training 준비를 위한 file generation.py 파일 복사
# !cp '/content/gdrive/MyDrive/ConcreteCrack_Detection/files_generation.py' .

# %%
# file generation for training
# !python files_generation.py
# Out:
# [classes.names] is created
# [custom_data.data] is created
# [train.txt] is created
# [test.txt] is created

# %%
# Custom Yolo training 을 위한 파일 복사
# !cp -r custom '/content/gdrive/MyDrive/ConcreteCrack_Detection'

# %%
# Yolo3 cfg 파일 이동
# !mv '/content/gdrive/MyDrive/ConcreteCrack_Detection/custom-train-yolo3.cfg' '/content/gdrive/MyDrive/ConcreteCrack_Detection/custom/'
# !mv '/content/gdrive/MyDrive/ConcreteCrack_Detection/custom-test-yolo3.cfg' '/content/gdrive/MyDrive/ConcreteCrack_Detection/custom/'
